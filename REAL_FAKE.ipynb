# %%
import pandas as pd
import numpy as np

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\KIIT0001\OneDrive\Desktop\adlab_pj\medicine\dataset

# %%
import os

BASE_DIR = r"c:\Users\KIIT0001\OneDrive\Desktop\adlab_pj\medicine\dataset"

print("Dataset exists:", os.path.exists(BASE_DIR))
print("Contents of dataset:", os.listdir(BASE_DIR))
# Out:
# Dataset exists: True
# Contents of dataset: ['.git', '.gitattributes', 'app1.py', 'Fake', 'model', 'Real', 'real_1.py', 'REAL_FAKE.ipynb', 'requirment.txt', 'test', 'train', 'val']

# %%
train_dir = BASE_DIR + r"\train"
print("Train exists:", os.path.exists(train_dir))
print("Train contents:", os.listdir(train_dir))
# Out:
# Train exists: True
# Train contents: ['Fake', 'Real']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

BASE_DIR = r"c:\Users\KIIT0001\OneDrive\Desktop\adlab_pj\medicine\dataset"


datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_gen = datagen.flow_from_directory(
    BASE_DIR,
    target_size=(224, 224),
    batch_size=32,
    class_mode="binary",
    subset="training"
)

val_gen = datagen.flow_from_directory(
    BASE_DIR,
    target_size=(224, 224),
    batch_size=32,
    class_mode="binary",
    subset="validation"
)
# Out:
# Found 1781 images belonging to 7 classes.
# Found 443 images belonging to 7 classes.

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D,
    Flatten, Dense, Dropout
)
from tensorflow.keras.optimizers import Adam


BASE_DIR = r"c:\Users\KIIT0001\OneDrive\Desktop\adlab_pj\medicine\dataset"

if not os.path.exists(BASE_DIR):
    raise FileNotFoundError(f"Dataset not found at {BASE_DIR}")


datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    validation_split=0.2
)

train_gen = datagen.flow_from_directory(
    BASE_DIR,
    target_size=(224, 224),
    batch_size=32,
    class_mode="binary",
    subset="training",
    shuffle=True
)

val_gen = datagen.flow_from_directory(
    BASE_DIR,
    target_size=(224, 224),
    batch_size=32,
    class_mode="binary",
    subset="validation",
    shuffle=False
)

print("Class indices:", train_gen.class_indices)

model = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(224,224,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation="relu"),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation="relu"),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(1, activation="sigmoid")
])

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()



history = model.fit(
    train_gen,
    epochs=10,
    validation_data=val_gen
)

model.save("real_fake_model.h5")
print(" Model saved as real_fake_model.h5")
# Out:
# Found 1781 images belonging to 7 classes.
# Found 443 images belonging to 7 classes.
# Class indices: {'.git': 0, 'Fake': 1, 'Real': 2, 'model': 3, 'test': 4, 'train': 5, 'val': 6}
# c:\Users\KIIT0001\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    11,075,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,169,089 (42.61 MB)
#  Trainable params: 11,169,089 (42.61 MB)
#  Non-trainable params: 0 (0.00 B)
# c:\Users\KIIT0001\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 196s 3s/step - accuracy: 0.1244 - loss: -841.9998 - val_accuracy: 0.1084 - val_loss: -14118.6436
# Epoch 2/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step - accuracy: 0.1121 - loss: -71161.0859 - val_accuracy: 0.1084 - val_loss: -441639.5625
# Epoch 3/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 44s 782ms/step - accuracy: 0.1163 - loss: -1222881.3750 - val_accuracy: 0.1084 - val_loss: -4086782.7500
# Epoch 4/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 42s 750ms/step - accuracy: 0.0949 - loss: -8779597.0000 - val_accuracy: 0.1084 - val_loss: -20161462.0000
# Epoch 5/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 40s 710ms/step - accuracy: 0.1053 - loss: -36880164.0000 - val_accuracy: 0.1084 - val_loss: -67455008.0000
# Epoch 6/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 40s 718ms/step - accuracy: 0.1035 - loss: -114810968.0000 - val_accuracy: 0.1084 - val_loss: -177840272.0000
# Epoch 7/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 43s 767ms/step - accuracy: 0.1057 - loss: -287683648.0000 - val_accuracy: 0.1084 - val_loss: -400013216.0000
# Epoch 8/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 733ms/step - accuracy: 0.1129 - loss: -604785984.0000 - val_accuracy: 0.1084 - val_loss: -803044608.0000
# Epoch 9/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 41s 727ms/step - accuracy: 0.1004 - loss: -1241427456.0000 - val_accuracy: 0.1084 - val_loss: -1471036416.0000
# Epoch 10/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 42s 747ms/step - accuracy: 0.1127 - loss: -2181316864.0000 - val_accuracy: 0.1084 - val_loss: -2509141760.0000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#  Model saved as real_fake_model.h5
